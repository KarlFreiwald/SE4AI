# %% [markdown]
# # Computing initialization images

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

from helpers import load_data_from_pickle

# %%
# Replace with your own database download directory
# base_path = 'E:/input'
base_path = r'C:\Users\kfrei\OneDrive - Ostbayerische Technische Hochschule Regensburg\Desktop\input'

# %%
x_train, y_train, x_val, y_val, x_test, y_test = load_data_from_pickle()

# %% [markdown]
# ## Computing the Average Images

# %%
# Compute the average images
avg_image_train = np.mean(x_train, axis=0)
avg_image_val = np.mean(x_val, axis=0)
avg_image_test = np.mean(x_test, axis=0)

# %%
# Saving the average images as pickle files
with open('average_images/avg_image_train.pkl', 'wb') as f:
    pickle.dump(avg_image_train, f)

with open('average_images/avg_image_val.pkl', 'wb') as f:
    pickle.dump(avg_image_val, f)

with open('average_images/avg_image_test.pkl', 'wb') as f:
    pickle.dump(avg_image_test, f)

# %%
avg_image_train.shape
# Out:
# (32, 32, 3)

# %%
# Plot all average images in one figure
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].imshow((avg_image_train * 255).astype('uint8'))
axs[0].set_title('Average Image of x_train')
axs[0].axis('off')

axs[1].imshow((avg_image_val * 255).astype('uint8'))
axs[1].set_title('Average Image of x_val')
axs[1].axis('off')

axs[2].imshow((avg_image_test * 255).astype('uint8'))
axs[2].set_title('Average Image of x_test')
axs[2].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Computing a random image

# %%
random_image = np.random.rand(32, 32, 3)

# %%
with open('average_images/random_image.pkl', 'wb') as f:
    pickle.dump(random_image, f)

# %%
plt.imshow((random_image * 255).astype('uint8'))
plt.title('Random Image')
plt.grid(False)
